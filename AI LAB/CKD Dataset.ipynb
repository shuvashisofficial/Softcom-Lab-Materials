# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import PrecisionRecallDisplay
from imblearn.metrics import geometric_mean_score
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_dataset = pd.read_csv('/content/drive/MyDrive/ml/train.csv')
test_dataset= pd.read_csv('/content/drive/MyDrive/ml/test.csv')

# %%
train_dataset
# Out:
#       id GENDER  AGE  Diabetes  Serum Creatinine Level  Obesity  \
# 0      1      M   69         1                       2        2
# 1      2      M   74         2                       1        1
# 2      3      F   59         1                       1        1
# 3      4      M   63         2                       2        2
# 4      5      F   63         1                       2        1
# ..   ...    ...  ...       ...                     ...      ...
# 787  923      F   56         1                       1        1
# 788  924      M   70         2                       1        1
# 789  925      M   58         2                       1        1
# 790  926      M   67         2                       1        2
# 791  927      M   62         1                       1        1
#
#      PEER_PRESSURE  CHRONIC DISEASE  FATIGUE   ALLERGY   \
# 0                1                1         2         1
# 1                1                2         2         2
# 2                2                1         2         1
# 3                1                1         1         1
# 4                1                1         1         1
# ..             ...              ...       ...       ...
# 787              2                2         2         1
# 788              1                1         2         2
# 789              1                1         1         2
# 790              1                1         2         2
# 791              2                1         2         2
#
#      Albumin-to-Creatinine Ratio  ALCOHOL CONSUMING  Blood Pressure  \
# 0                              2                  2               2
# 1                              1                  1               1
# 2                              2                  1               2
# 3                              1                  2               1
# 4                              2                  1               2
# ..                           ...                ...             ...
# 787                            1                  2               2
# 788                            2                  2               2
# 789                            2                  2               2
# 790                            1                  2               2
# 791                            2                  2               1
#
#      Blood Urea Nitrogen (BUN) Leve  Urinary Protein (Proteinuria):   \
# 0                                 2                                2
# 1                                 2                                2
# 2                                 2                                1
# 3                                 1                                2
# 4                                 2                                1
# ..                              ...                              ...
# 787                               2                                2
# 788                               2                                1
# 789                               1                                1
# 790                               2                                1
# 791                               1                                2
#
#      Urinary Tract Infections  CKD_Disease
# 0                            2         YES
# 1                            2         YES
# 2                            2          NO
# 3                            2          NO
# 4                            1          NO
# ..                         ...         ...
# 787                          1         YES
# 788                          2         YES
# 789                          2         YES
# 790                          2         YES
# 791                          1         YES
#
# [792 rows x 17 columns]

# %%
train_dataset.columns
# Out:
# Index(['id', 'GENDER', 'AGE', 'Diabetes', 'Serum Creatinine Level', 'Obesity',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ',
#        'Albumin-to-Creatinine Ratio', 'ALCOHOL CONSUMING', 'Blood Pressure',
#        'Blood Urea Nitrogen (BUN) Leve', 'Urinary Protein (Proteinuria): ',
#        'Urinary Tract Infections ', 'CKD_Disease'],
#       dtype='object')

# %%
test_dataset
# Out:
#      id GENDER  AGE  Diabetes  Serum Creatinine Level  Obesity  PEER_PRESSURE  \
# 0   209      M   67         1                       2        2              2
# 1   210      M   55         2                       1        1              1
# 2   211      M   54         2                       1        1              1
# 3   212      F   77         1                       2        2              2
# 4   213      M   58         2                       1        1              1
# ..  ...    ...  ...       ...                     ...      ...            ...
# 85  294      F   56         2                       2        2              1
# 86  295      M   67         1                       1        1              2
# 87  296      F   54         2                       2        2              1
# 88  297      M   63         1                       2        1              1
# 89  298      F   47         2                       2        1              2
#
#     CHRONIC DISEASE  FATIGUE   ALLERGY   Albumin-to-Creatinine Ratio  \
# 0                 1         2         2                            1
# 1                 1         2         2                            2
# 2                 1         1         2                            2
# 3                 2         2         2                            2
# 4                 1         2         2                            2
# ..              ...       ...       ...                          ...
# 85                1         2         2                            1
# 86                1         2         1                            2
# 87                2         1         1                            2
# 88                1         2         1                            2
# 89                2         2         2                            2
#
#     ALCOHOL CONSUMING  Blood Pressure  Blood Urea Nitrogen (BUN) Leve  \
# 0                   1               2                               1
# 1                   2               2                               2
# 2                   2               2                               1
# 3                   1               2                               2
# 4                   2               2                               2
# ..                ...             ...                             ...
# 85                  1               1                               2
# 86                  1               2                               2
# 87                  2               1                               2
# 88                  2               2                               2
# 89                  1               2                               2
#
#     Urinary Protein (Proteinuria):   Urinary Tract Infections
# 0                                 2                          1
# 1                                 1                          2
# 2                                 1                          1
# 3                                 2                          2
# 4                                 1                          2
# ..                              ...                        ...
# 85                                1                          2
# 86                                1                          2
# 87                                2                          2
# 88                                1                          1
# 89                                1                          1
#
# [90 rows x 16 columns]

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               792 non-null    int64
#  1   GENDER                           792 non-null    object
#  2   AGE                              792 non-null    int64
#  3   Diabetes                         792 non-null    int64
#  4   Serum Creatinine Level           792 non-null    int64
#  5   Obesity                          792 non-null    int64
#  6   PEER_PRESSURE                    792 non-null    int64
#  7   CHRONIC DISEASE                  792 non-null    int64
#  8   FATIGUE                          792 non-null    int64
#  9   ALLERGY                          792 non-null    int64
#  10  Albumin-to-Creatinine Ratio      792 non-null    int64
#  11  ALCOHOL CONSUMING                792 non-null    int64
#  12  Blood Pressure                   792 non-null    int64
#  13  Blood Urea Nitrogen (BUN) Leve   792 non-null    int64
#  14  Urinary Protein (Proteinuria):   792 non-null    int64
#  15  Urinary Tract Infections         792 non-null    int64
#  16  CKD_Disease                      792 non-null    object
# dtypes: int64(15), object(2)
# memory usage: 105.3+ KB

# %%
label_dataset = pd.read_csv('/content/drive/MyDrive/ml/output.csv')

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
train_dataset['GENDER']= label_encoder.fit_transform(train_dataset['GENDER'])
train_dataset['CKD_Disease']= label_encoder.fit_transform(train_dataset['CKD_Disease'])

test_dataset['GENDER']= label_encoder.fit_transform(test_dataset['GENDER'])
label_dataset['CKD_Disease']= label_encoder.fit_transform(label_dataset['CKD_Disease'])

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               792 non-null    int64
#  1   GENDER                           792 non-null    int64
#  2   AGE                              792 non-null    int64
#  3   Diabetes                         792 non-null    int64
#  4   Serum Creatinine Level           792 non-null    int64
#  5   Obesity                          792 non-null    int64
#  6   PEER_PRESSURE                    792 non-null    int64
#  7   CHRONIC DISEASE                  792 non-null    int64
#  8   FATIGUE                          792 non-null    int64
#  9   ALLERGY                          792 non-null    int64
#  10  Albumin-to-Creatinine Ratio      792 non-null    int64
#  11  ALCOHOL CONSUMING                792 non-null    int64
#  12  Blood Pressure                   792 non-null    int64
#  13  Blood Urea Nitrogen (BUN) Leve   792 non-null    int64
#  14  Urinary Protein (Proteinuria):   792 non-null    int64
#  15  Urinary Tract Infections         792 non-null    int64
#  16  CKD_Disease                      792 non-null    int64
# dtypes: int64(17)
# memory usage: 105.3 KB

# %%
test_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               90 non-null     int64
#  1   GENDER                           90 non-null     int64
#  2   AGE                              90 non-null     int64
#  3   Diabetes                         90 non-null     int64
#  4   Serum Creatinine Level           90 non-null     int64
#  5   Obesity                          90 non-null     int64
#  6   PEER_PRESSURE                    90 non-null     int64
#  7   CHRONIC DISEASE                  90 non-null     int64
#  8   FATIGUE                          90 non-null     int64
#  9   ALLERGY                          90 non-null     int64
#  10  Albumin-to-Creatinine Ratio      90 non-null     int64
#  11  ALCOHOL CONSUMING                90 non-null     int64
#  12  Blood Pressure                   90 non-null     int64
#  13  Blood Urea Nitrogen (BUN) Leve   90 non-null     int64
#  14  Urinary Protein (Proteinuria):   90 non-null     int64
#  15  Urinary Tract Infections         90 non-null     int64
# dtypes: int64(16)
# memory usage: 11.4 KB

# %%
train_dataset.describe()
# Out:
#                id      GENDER        AGE    Diabetes  Serum Creatinine Level  \
# count  792.000000  792.000000  792.00000  792.000000              792.000000
# mean   455.818182    0.522727   62.52399    1.570707                1.569444
# std    288.450260    0.499799    8.24357    0.495288                0.495467
# min      1.000000    0.000000   21.00000    1.000000                1.000000
# 25%    198.750000    0.000000   57.00000    1.000000                1.000000
# 50%    396.500000    1.000000   62.00000    2.000000                2.000000
# 75%    729.250000    1.000000   69.00000    2.000000                2.000000
# max    927.000000    1.000000   87.00000    2.000000                2.000000
#
#           Obesity  PEER_PRESSURE  CHRONIC DISEASE    FATIGUE     ALLERGY   \
# count  792.000000     792.000000       792.000000  792.000000  792.000000
# mean     1.501263       1.491162         1.500000    1.670455    1.551768
# std      0.500314       0.500238         0.500316    0.470345    0.497627
# min      1.000000       1.000000         1.000000    1.000000    1.000000
# 25%      1.000000       1.000000         1.000000    1.000000    1.000000
# 50%      2.000000       1.000000         1.500000    2.000000    2.000000
# 75%      2.000000       2.000000         2.000000    2.000000    2.000000
# max      2.000000       2.000000         2.000000    2.000000    2.000000
#
#        Albumin-to-Creatinine Ratio  ALCOHOL CONSUMING  Blood Pressure  \
# count                   792.000000         792.000000      792.000000
# mean                      1.554293           1.555556        1.580808
# std                       0.497358           0.497218        0.493739
# min                       1.000000           1.000000        1.000000
# 25%                       1.000000           1.000000        1.000000
# 50%                       2.000000           2.000000        2.000000
# 75%                       2.000000           2.000000        2.000000
# max                       2.000000           2.000000        2.000000
#
#        Blood Urea Nitrogen (BUN) Leve  Urinary Protein (Proteinuria):   \
# count                      792.000000                       792.000000
# mean                         1.652778                         1.477273
# std                          0.476388                         0.499799
# min                          1.000000                         1.000000
# 25%                          1.000000                         1.000000
# 50%                          2.000000                         1.000000
# 75%                          2.000000                         2.000000
# max                          2.000000                         2.000000
#
#        Urinary Tract Infections   CKD_Disease
# count                 792.000000   792.000000
# mean                    1.558081     0.869949
# std                     0.496929     0.336572
# min                     1.000000     0.000000
# 25%                     1.000000     1.000000
# 50%                     2.000000     1.000000
# 75%                     2.000000     1.000000
# max                     2.000000     1.000000

# %%
train_dataset.corr()
# Out:
#                                        id    GENDER       AGE  Diabetes  \
# id                               1.000000  0.003887  0.015318 -0.002317
# GENDER                           0.003887  1.000000  0.021193  0.044571
# AGE                              0.015318  0.021193  1.000000 -0.088507
# Diabetes                        -0.002317  0.044571 -0.088507  1.000000
# Serum Creatinine Level          -0.006962 -0.213143  0.011044 -0.017459
# Obesity                          0.006651 -0.149259  0.054861  0.155244
# PEER_PRESSURE                    0.013420 -0.279832  0.023964 -0.045949
# CHRONIC DISEASE                 -0.011791 -0.202229 -0.017625 -0.127544
# FATIGUE                          0.025146 -0.094480  0.018833 -0.032808
# ALLERGY                          0.018958  0.150296  0.023735  0.003083
# Albumin-to-Creatinine Ratio     -0.001526  0.150147  0.066902 -0.136209
# ALCOHOL CONSUMING               -0.007545  0.468025  0.054730 -0.026238
# Blood Pressure                   0.005509  0.135994  0.183247 -0.131959
# Blood Urea Nitrogen (BUN) Leve  -0.003809 -0.080972 -0.017352  0.058641
# Urinary Protein (Proteinuria):  -0.013621 -0.078905 -0.008306  0.037142
# Urinary Tract Infections        -0.017663  0.386623  0.004752  0.121980
# CKD_Disease                      0.023482  0.073958  0.091572  0.074191
#
#                                  Serum Creatinine Level   Obesity  \
# id                                            -0.006962  0.006651
# GENDER                                        -0.213143 -0.149259
# AGE                                            0.011044  0.054861
# Diabetes                                      -0.017459  0.155244
# Serum Creatinine Level                         1.000000  0.586140
# Obesity                                        0.586140  1.000000
# PEER_PRESSURE                                  0.334027  0.237456
# CHRONIC DISEASE                                0.038250 -0.012626
# FATIGUE                                       -0.126807 -0.188948
# ALLERGY                                       -0.153041 -0.167831
# Albumin-to-Creatinine Ratio                   -0.082013 -0.193337
# ALCOHOL CONSUMING                             -0.274832 -0.160365
# Blood Pressure                                -0.010049 -0.217920
# Blood Urea Nitrogen (BUN) Leve                -0.114635 -0.149328
# Urinary Protein (Proteinuria):                 0.381614  0.513273
# Urinary Tract Infections                      -0.106260 -0.104537
# CKD_Disease                                    0.186895  0.154883
#
#                                  PEER_PRESSURE  CHRONIC DISEASE  FATIGUE   \
# id                                    0.013420        -0.011791  0.025146
# GENDER                               -0.279832        -0.202229 -0.094480
# AGE                                   0.023964        -0.017625  0.018833
# Diabetes                             -0.045949        -0.127544 -0.032808
# Serum Creatinine Level                0.334027         0.038250 -0.126807
# Obesity                               0.237456        -0.012626 -0.188948
# PEER_PRESSURE                         1.000000         0.047987  0.076262
# CHRONIC DISEASE                       0.047987         1.000000 -0.110133
# FATIGUE                               0.076262        -0.110133  1.000000
# ALLERGY                              -0.079417         0.109173 -0.005340
# Albumin-to-Creatinine Ratio          -0.064126        -0.058426  0.127922
# ALCOHOL CONSUMING                    -0.158131        -0.005082 -0.205420
# Blood Pressure                       -0.071324        -0.174005  0.139314
# Blood Urea Nitrogen (BUN) Leve       -0.222442        -0.018565  0.453489
# Urinary Protein (Proteinuria):        0.380963         0.065724 -0.147525
# Urinary Tract Infections             -0.102190        -0.040679 -0.028889
# CKD_Disease                           0.207165         0.116368  0.136216
#
#                                  ALLERGY   Albumin-to-Creatinine Ratio  \
# id                               0.018958                    -0.001526
# GENDER                           0.150296                     0.150147
# AGE                              0.023735                     0.066902
# Diabetes                         0.003083                    -0.136209
# Serum Creatinine Level          -0.153041                    -0.082013
# Obesity                         -0.167831                    -0.193337
# PEER_PRESSURE                   -0.079417                    -0.064126
# CHRONIC DISEASE                  0.109173                    -0.058426
# FATIGUE                         -0.005340                     0.127922
# ALLERGY                          1.000000                     0.172517
# Albumin-to-Creatinine Ratio      0.172517                     1.000000
# ALCOHOL CONSUMING                0.333249                     0.266402
# Blood Pressure                   0.186197                     0.391395
# Blood Urea Nitrogen (BUN) Leve  -0.049403                     0.023640
# Urinary Protein (Proteinuria):  -0.079134                     0.048200
# Urinary Tract Infections         0.230665                     0.153468
# CKD_Disease                      0.315756                     0.242369
#
#                                  ALCOHOL CONSUMING  Blood Pressure  \
# id                                       -0.007545        0.005509
# GENDER                                    0.468025        0.135994
# AGE                                       0.054730        0.183247
# Diabetes                                 -0.026238       -0.131959
# Serum Creatinine Level                   -0.274832       -0.010049
# Obesity                                  -0.160365       -0.217920
# PEER_PRESSURE                            -0.158131       -0.071324
# CHRONIC DISEASE                          -0.005082       -0.174005
# FATIGUE                                  -0.205420        0.139314
# ALLERGY                                   0.333249        0.186197
# Albumin-to-Creatinine Ratio               0.266402        0.391395
# ALCOHOL CONSUMING                         1.000000        0.197976
# Blood Pressure                            0.197976        1.000000
# Blood Urea Nitrogen (BUN) Leve           -0.204001        0.256499
# Urinary Protein (Proteinuria):           -0.020349       -0.171856
# Urinary Tract Infections                  0.350204        0.083900
# CKD_Disease                               0.288745        0.249707
#
#                                  Blood Urea Nitrogen (BUN) Leve  \
# id                                                    -0.003809
# GENDER                                                -0.080972
# AGE                                                   -0.017352
# Diabetes                                               0.058641
# Serum Creatinine Level                                -0.114635
# Obesity                                               -0.149328
# PEER_PRESSURE                                         -0.222442
# CHRONIC DISEASE                                       -0.018565
# FATIGUE                                                0.453489
# ALLERGY                                               -0.049403
# Albumin-to-Creatinine Ratio                            0.023640
# ALCOHOL CONSUMING                                     -0.204001
# Blood Pressure                                         0.256499
# Blood Urea Nitrogen (BUN) Leve                         1.000000
# Urinary Protein (Proteinuria):                        -0.184511
# Urinary Tract Infections                              -0.002819
# CKD_Disease                                            0.049170
#
#                                  Urinary Protein (Proteinuria):   \
# id                                                     -0.013621
# GENDER                                                 -0.078905
# AGE                                                    -0.008306
# Diabetes                                                0.037142
# Serum Creatinine Level                                  0.381614
# Obesity                                                 0.513273
# PEER_PRESSURE                                           0.380963
# CHRONIC DISEASE                                         0.065724
# FATIGUE                                                -0.147525
# ALLERGY                                                -0.079134
# Albumin-to-Creatinine Ratio                             0.048200
# ALCOHOL CONSUMING                                      -0.020349
# Blood Pressure                                         -0.171856
# Blood Urea Nitrogen (BUN) Leve                         -0.184511
# Urinary Protein (Proteinuria):                          1.000000
# Urinary Tract Infections                                0.066404
# CKD_Disease                                             0.256719
#
#                                  Urinary Tract Infections   CKD_Disease
# id                                               -0.017663     0.023482
# GENDER                                            0.386623     0.073958
# AGE                                               0.004752     0.091572
# Diabetes                                          0.121980     0.074191
# Serum Creatinine Level                           -0.106260     0.186895
# Obesity                                          -0.104537     0.154883
# PEER_PRESSURE                                    -0.102190     0.207165
# CHRONIC DISEASE                                  -0.040679     0.116368
# FATIGUE                                          -0.028889     0.136216
# ALLERGY                                           0.230665     0.315756
# Albumin-to-Creatinine Ratio                       0.153468     0.242369
# ALCOHOL CONSUMING                                 0.350204     0.288745
# Blood Pressure                                    0.083900     0.249707
# Blood Urea Nitrogen (BUN) Leve                   -0.002819     0.049170
# Urinary Protein (Proteinuria):                    0.066404     0.256719
# Urinary Tract Infections                          1.000000     0.192615
# CKD_Disease                                       0.192615     1.000000

# %%
train_dataset.CKD_Disease.value_counts().plot.bar(color=['cyan', 'lightblue'],title="Affected(1) vs Healthy(0)", xlabel="Output class", ylabel = "Count")
# Out:
# <Axes: title={'center': 'Affected(1) vs Healthy(0)'}, xlabel='Output class', ylabel='Count'>

# %%
temp = train_dataset.query('CKD_Disease == 0')
sns.set_theme()
sns.displot(data=temp.GENDER).set(title="Distribution of Gender Among CKD Diseases Classes", xlabel="GENDER")

# %%
train_dataset
# Out:
#       id  GENDER  AGE  Diabetes  Serum Creatinine Level  Obesity  \
# 0      1       1   69         1                       2        2
# 1      2       1   74         2                       1        1
# 2      3       0   59         1                       1        1
# 3      4       1   63         2                       2        2
# 4      5       0   63         1                       2        1
# ..   ...     ...  ...       ...                     ...      ...
# 787  923       0   56         1                       1        1
# 788  924       1   70         2                       1        1
# 789  925       1   58         2                       1        1
# 790  926       1   67         2                       1        2
# 791  927       1   62         1                       1        1
#
#      PEER_PRESSURE  CHRONIC DISEASE  FATIGUE   ALLERGY   \
# 0                1                1         2         1
# 1                1                2         2         2
# 2                2                1         2         1
# 3                1                1         1         1
# 4                1                1         1         1
# ..             ...              ...       ...       ...
# 787              2                2         2         1
# 788              1                1         2         2
# 789              1                1         1         2
# 790              1                1         2         2
# 791              2                1         2         2
#
#      Albumin-to-Creatinine Ratio  ALCOHOL CONSUMING  Blood Pressure  \
# 0                              2                  2               2
# 1                              1                  1               1
# 2                              2                  1               2
# 3                              1                  2               1
# 4                              2                  1               2
# ..                           ...                ...             ...
# 787                            1                  2               2
# 788                            2                  2               2
# 789                            2                  2               2
# 790                            1                  2               2
# 791                            2                  2               1
#
#      Blood Urea Nitrogen (BUN) Leve  Urinary Protein (Proteinuria):   \
# 0                                 2                                2
# 1                                 2                                2
# 2                                 2                                1
# 3                                 1                                2
# 4                                 2                                1
# ..                              ...                              ...
# 787                               2                                2
# 788                               2                                1
# 789                               1                                1
# 790                               2                                1
# 791                               1                                2
#
#      Urinary Tract Infections   CKD_Disease
# 0                            2            1
# 1                            2            1
# 2                            2            0
# 3                            2            0
# 4                            1            0
# ..                         ...          ...
# 787                          1            1
# 788                          2            1
# 789                          2            1
# 790                          2            1
# 791                          1            1
#
# [792 rows x 17 columns]

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               792 non-null    int64
#  1   GENDER                           792 non-null    int64
#  2   AGE                              792 non-null    int64
#  3   Diabetes                         792 non-null    int64
#  4   Serum Creatinine Level           792 non-null    int64
#  5   Obesity                          792 non-null    int64
#  6   PEER_PRESSURE                    792 non-null    int64
#  7   CHRONIC DISEASE                  792 non-null    int64
#  8   FATIGUE                          792 non-null    int64
#  9   ALLERGY                          792 non-null    int64
#  10  Albumin-to-Creatinine Ratio      792 non-null    int64
#  11  ALCOHOL CONSUMING                792 non-null    int64
#  12  Blood Pressure                   792 non-null    int64
#  13  Blood Urea Nitrogen (BUN) Leve   792 non-null    int64
#  14  Urinary Protein (Proteinuria):   792 non-null    int64
#  15  Urinary Tract Infections         792 non-null    int64
#  16  CKD_Disease                      792 non-null    int64
# dtypes: int64(17)
# memory usage: 105.3 KB

# %%
test_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               90 non-null     int64
#  1   GENDER                           90 non-null     int64
#  2   AGE                              90 non-null     int64
#  3   Diabetes                         90 non-null     int64
#  4   Serum Creatinine Level           90 non-null     int64
#  5   Obesity                          90 non-null     int64
#  6   PEER_PRESSURE                    90 non-null     int64
#  7   CHRONIC DISEASE                  90 non-null     int64
#  8   FATIGUE                          90 non-null     int64
#  9   ALLERGY                          90 non-null     int64
#  10  Albumin-to-Creatinine Ratio      90 non-null     int64
#  11  ALCOHOL CONSUMING                90 non-null     int64
#  12  Blood Pressure                   90 non-null     int64
#  13  Blood Urea Nitrogen (BUN) Leve   90 non-null     int64
#  14  Urinary Protein (Proteinuria):   90 non-null     int64
#  15  Urinary Tract Infections         90 non-null     int64
# dtypes: int64(16)
# memory usage: 11.4 KB

# %%
label_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           90 non-null     int64
#  1   CKD_Disease  90 non-null     int64
# dtypes: int64(2)
# memory usage: 1.5 KB

# %%
X_train = train_dataset.iloc[:, 1:16].values
y_train = train_dataset.iloc[:, 16].values

# %%
X_test = test_dataset.iloc[:, 1:].values
y_test = label_dataset.iloc[:, 1].values

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (792, 15)
# (792,)
# (90, 15)
# (90,)

# %% [markdown]
# LogisticRegression

# %%
clf = LogisticRegression(random_state = 0,C=2,penalty= 'l2').fit(X_train, y_train)
Y_pred = clf.predict(X_test)
clf.predict_proba(X_test)

cm = confusion_matrix(y_test, Y_pred)
cmd = ConfusionMatrixDisplay(cm, display_labels=['Affected','Healthy'])
cmd.plot(cmap=plt.cm.Blues)
print('Accuracy score: ', accuracy_score(y_test, Y_pred))
print('F1 score: ', f1_score(y_test, Y_pred))
print('Precision score: ', precision_score(y_test, Y_pred))
print('Recall score: ', recall_score(y_test, Y_pred))
from sklearn.metrics import RocCurveDisplay
rfc_disp = RocCurveDisplay.from_estimator(clf, X_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy score:  0.9555555555555556
# F1 score:  0.9743589743589742
# Precision score:  0.9620253164556962
# Recall score:  0.987012987012987

# %% [markdown]
# SVM

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
clf = make_pipeline(StandardScaler(), SVC(kernel = 'linear',C = 0.1))
clf.fit(X_train, y_train)
Y_pred= clf.predict(X_test)

cm = confusion_matrix(y_test, Y_pred)
cmd = ConfusionMatrixDisplay(cm, display_labels=['Affected','Healthy'])
cmd.plot(cmap=plt.cm.Blues)
print('Accuracy score: ', accuracy_score(y_test, Y_pred))
print('F1 score: ', f1_score(y_test, Y_pred))
print('Precision score: ', precision_score(y_test, Y_pred))
print('Recall score: ', recall_score(y_test, Y_pred))
from sklearn.metrics import RocCurveDisplay
rfc_disp = RocCurveDisplay.from_estimator(clf, X_test, y_test)
# Out:
# Accuracy score:  0.9666666666666667
# F1 score:  0.9806451612903225
# Precision score:  0.9743589743589743
# Recall score:  0.987012987012987

# %% [markdown]
# GaussianNB

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
Y_pred = gnb.predict(X_test)

cm = confusion_matrix(y_test, Y_pred)
cmd = ConfusionMatrixDisplay(cm, display_labels=['Affected','Healthy'])
cmd.plot(cmap=plt.cm.Blues)
print('Accuracy score: ', accuracy_score(y_test, Y_pred))
print('F1 score: ', f1_score(y_test, Y_pred))
print('Precision score: ', precision_score(y_test, Y_pred))
print('Recall score: ', recall_score(y_test, Y_pred))
from sklearn.metrics import RocCurveDisplay
rfc_disp = RocCurveDisplay.from_estimator(gnb, X_test, y_test)
# Out:
# Accuracy score:  0.9333333333333333
# F1 score:  0.9615384615384615
# Precision score:  0.9493670886075949
# Recall score:  0.974025974025974

# %% [markdown]
# KNeighborsClassifier

# %%
neigh = KNeighborsClassifier(leaf_size = 1, n_neighbors = 11,p = 1)
neigh.fit(X_train, y_train)
Y_pred = neigh.predict(X_test)

cm = confusion_matrix(y_test, Y_pred)
cmd = ConfusionMatrixDisplay(cm, display_labels=['Affected','Healthy'])
cmd.plot(cmap=plt.cm.Blues)
print('Accuracy score: ', accuracy_score(y_test, Y_pred))
print('F1 score: ', f1_score(y_test, Y_pred))
print('Precision score: ', precision_score(y_test, Y_pred))
print('Recall score: ', recall_score(y_test, Y_pred))
from sklearn.metrics import RocCurveDisplay
rfc_disp = RocCurveDisplay.from_estimator(neigh, X_test, y_test)
# Out:
# Accuracy score:  0.9111111111111111
# F1 score:  0.9506172839506173
# Precision score:  0.9058823529411765
# Recall score:  1.0

# %% [markdown]
# RandomForestClassifier

# %%
rf = RandomForestClassifier(max_depth = 4,random_state = 0)
rf.fit(X_train, y_train)
Y_pred = rf.predict(X_test)

cm = confusion_matrix(y_test, Y_pred)
cmd = ConfusionMatrixDisplay(cm, display_labels=['Affected','Honesty'])
cmd.plot(cmap=plt.cm.Blues)
print('Accuracy score: ', accuracy_score(y_test, Y_pred))
print('F1 score: ', f1_score(y_test, Y_pred))
print('Precision score: ', precision_score(y_test, Y_pred))
print('Recall score: ', recall_score(y_test, Y_pred))
from sklearn.metrics import RocCurveDisplay
rfc_disp = RocCurveDisplay.from_estimator(rf, X_test, y_test)
# Out:
# Accuracy score:  0.9222222222222223
# F1 score:  0.9565217391304348
# Precision score:  0.9166666666666666
# Recall score:  1.0

# %% [markdown]
# DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(random_state = 1000,max_depth = 4,min_samples_leaf = 1)
dt.fit(X_train, y_train)
Y_pred = dt.predict(X_test)

cm = confusion_matrix(y_test, Y_pred)
cmd = ConfusionMatrixDisplay(cm, display_labels=['Affected','Healthy'])
cmd.plot(cmap=plt.cm.Blues)
print('Accuracy score: ', accuracy_score(y_test, Y_pred))
print('F1 score: ', f1_score(y_test, Y_pred))
print('Precision score: ', precision_score(y_test, Y_pred))
print('Recall score: ', recall_score(y_test, Y_pred))
from sklearn.metrics import RocCurveDisplay
rfc_disp = RocCurveDisplay.from_estimator(dt, X_test, y_test)
# Out:
# Accuracy score:  0.9111111111111111
# F1 score:  0.95
# Precision score:  0.9156626506024096
# Recall score:  0.987012987012987
